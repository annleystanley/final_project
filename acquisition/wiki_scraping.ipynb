# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_Academy_Award-winning_films'
tables = pd.read_html(url) 
tables[0]
# Out:
#                                                    Film  Year Awards  \
# 0                                                  CODA  2021      3
# 1                                                  Dune  2021      6
# 2                                The Eyes of Tammy Faye  2021      2
# 3                                        No Time to Die  2021      1
# 4                                  The Windshield Wiper  2021      1
# ...                                                 ...   ...    ...
# 1342                            The Yankee Doodle Mouse  1943      1
# 1343                                       The Yearling  1946      2
# 1344  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1345                         You Can't Take It with You  1938      2
# 1346                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0              3
# 1             10
# 2              2
# 3              3
# 4              1
# ...          ...
# 1342           1
# 1343           7
# 1344           1
# 1345           7
# 1346           7
#
# [1347 rows x 4 columns]

# %%
oscars_df = tables[0]

# %%
oscars_df
# Out:
#                                                    Film  Year Awards  \
# 0                                                  CODA  2021      3
# 1                                                  Dune  2021      6
# 2                                The Eyes of Tammy Faye  2021      2
# 3                                        No Time to Die  2021      1
# 4                                  The Windshield Wiper  2021      1
# ...                                                 ...   ...    ...
# 1342                            The Yankee Doodle Mouse  1943      1
# 1343                                       The Yearling  1946      2
# 1344  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1345                         You Can't Take It with You  1938      2
# 1346                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0              3
# 1             10
# 2              2
# 3              3
# 4              1
# ...          ...
# 1342           1
# 1343           7
# 1344           1
# 1345           7
# 1346           7
#
# [1347 rows x 4 columns]

# %%
# exporting raw dataframe
oscars_df.to_csv('oscars_raw_data.csv', index=False)
